# %%
import pandas as pd
import numpy as np
import json
from os import listdir
from os.path import isfile, join
import copy

# %%
#tomar peak o peak en promedio por tiempo. 
path = '/Users/davidbautista/Documents/tesis/luti-back/server/'
p = path + 'docs/escenario1/accesibility_ij'
rutas = [f for f in listdir(p) if isfile(join(p, f)) and 'accessibility ij' in f]

# %%
len(rutas)
# Out:
# 96773

# %%
filename = '{}docs/escenario1/totalporzonas.json'.format(path)
with open(filename, 'w') as fileout:
    json.dump(data3, fileout)

# %%
len(data3)
# Out:
# 128

# %%
data3 = [{'zone': i, 'value': 0} for i in range(128)]
prev = 1;
for ruta in rutas:
    prev += 1
    if prev % 1000 == 0:
        print(prev)
    df = pd.read_json(join(p, ruta))
    for index,row in df.iterrows():
        typefield = row['type']
        zona = int(row['zona_i_id'].replace("a", ""))
        data3[zona]['value'] += row['value']/96773
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000

# %%
filename = '{}docs/tpctmcar.json'.format(path)
with open(filename, 'w') as fileout:
    json.dump(data2, fileout)

# %%
data2 = [{'tpc': 0, 'tm':0, 'car':0, 'time': i} for i in range(42)]
prev = 1;
for ruta in rutas:
    prev += 1
    if prev % 1000 == 0:
        print(prev)
    df = pd.read_json(join(p, ruta))
    for index,row in df.iterrows():
        typefield = row['type']
        t = int(row['time'])
        data2[t][typefield] += row['value']/32258
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000

# %%
data = [{'peak': 0, 'opeak':0, 'time': i} for i in range(42)]
prev = 1;
for ruta in rutas:
    prev += 1
    if prev % 1000 == 0:
        print(prev)
    df = pd.read_json(join(p, ruta))
    for index,row in df.iterrows():
        mode = row['mode']
        t = int(row['time'])
        data[t][mode] += row['value']/48387
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000

# %%
filename = '{}docs/peaksopeaks.json'.format(path)
with open(filename, 'w') as fileout:
    json.dump(data, fileout)

# %%
len([f for f in listdir('{}docs/escenario1/'.format(path)) if isfile(join('{}docs/escenario1/'.format(path), f)) and 'accessibility ij' in f and ',tm,' in f])
# Out:
# 32258

# %%
32258
32257
32258

# %%
rutas3
# Out:
# ['accessibility ij[a70,a87,tm,opeak].json',
#  'accessibility ij[a2,a120,car,opeak].json',
#  'accessibility ij[a100,a107,car,opeak].json',
#  'accessibility ij[a70,a92,tm,opeak].json',
#  'accessibility ij[a36,a69,tm,opeak].json',
#  'accessibility ij[a119,a36,car,opeak].json',
#  'accessibility ij[a61,a37,tpc,opeak].json',
#  'accessibility ij[a58,a73,tpc,opeak].json',
#  'accessibility ij[a120,a72,car,opeak].json',
#  'accessibility ij[a22,a72,car,opeak].json',
#  'accessibility ij[a48,a106,car,opeak].json',
#  'accessibility ij[a12,a22,tpc,opeak].json',
#  'accessibility ij[a51,a67,car,opeak].json',
#  'accessibility ij[a110,a22,tpc,opeak].json',
#  'accessibility ij[a68,a23,car,opeak].json',
#  'accessibility ij[a88,a38,tpc,opeak].json',
#  'accessibility ij[a52,a122,tpc,opeak].json',
#  'accessibility ij[a116,a13,car,opeak].json',
#  'accessibility ij[a57,a56,tpc,opeak].json',
#  'accessibility ij[a14,a13,car,opeak].json',
#  'accessibility ij[a30,a118,tm,opeak].json',
# ...

# %%
pd.read_json(join(p, rutas3[11]))
# Out:
#    zona_i_id zona_j_id type   mode  time     value
# 0        a12       a22  tpc  opeak     0   8508.38
# 1        a12       a22  tpc  opeak     1   9087.95
# 2        a12       a22  tpc  opeak     2   9526.30
# 3        a12       a22  tpc  opeak     3  10120.80
# 4        a12       a22  tpc  opeak     4  10722.80
# 5        a12       a22  tpc  opeak     5  10795.50
# 6        a12       a22  tpc  opeak     6  10898.60
# 7        a12       a22  tpc  opeak     7  11020.80
# 8        a12       a22  tpc  opeak     8  11149.30
# 9        a12       a22  tpc  opeak     9  11282.20
# 10       a12       a22  tpc  opeak    10  11426.90
# 11       a12       a22  tpc  opeak    11  11583.80
# 12       a12       a22  tpc  opeak    12  11749.50
# 13       a12       a22  tpc  opeak    13  11921.40
# 14       a12       a22  tpc  opeak    14  12099.10
# 15       a12       a22  tpc  opeak    15  12282.90
# 16       a12       a22  tpc  opeak    16  12471.10
# ...

# %%
pd.read_json(join(p, rutas2[11]))
# Out:
#    zona_i_id zona_j_id type  mode  time    value
# 0       a109      a109   tm  peak     0   312727
# 1       a109      a109   tm  peak     1   324042
# 2       a109      a109   tm  peak     2   341853
# 3       a109      a109   tm  peak     3   353645
# 4       a109      a109   tm  peak     4   367221
# 5       a109      a109   tm  peak     5   384102
# 6       a109      a109   tm  peak     6   402505
# 7       a109      a109   tm  peak     7   414315
# 8       a109      a109   tm  peak     8   430617
# 9       a109      a109   tm  peak     9   446503
# 10      a109      a109   tm  peak    10   454128
# 11      a109      a109   tm  peak    11   428103
# 12      a109      a109   tm  peak    12   444015
# 13      a109      a109   tm  peak    13   454964
# 14      a109      a109   tm  peak    14   472945
# 15      a109      a109   tm  peak    15   494811
# 16      a109      a109   tm  peak    16   522723
# 17      a109      a109   tm  peak    17   548575
# ...

# %%
data
# Out:
# [{'peak': 194060.2852970335, 'opeak': 3012.936531504767, 'time': 0},
#  {'peak': 200331.9020610016, 'opeak': 3119.2172741954096, 'time': 1},
#  {'peak': 211123.8270259431, 'opeak': 3179.204856149807, 'time': 2},
#  {'peak': 217830.88793862824, 'opeak': 3223.168820355398, 'time': 3},
#  {'peak': 226158.71291630378, 'opeak': 3263.126310672622, 'time': 4},
#  {'peak': 236051.7355751312, 'opeak': 3301.347830424983, 'time': 5},
#  {'peak': 247038.1100800199, 'opeak': 3338.0203997983876, 'time': 6},
#  {'peak': 254091.24652970457, 'opeak': 3376.3939566315594, 'time': 7},
#  {'peak': 263979.61785667774, 'opeak': 3422.4217262202965, 'time': 8},
#  {'peak': 273642.0751462532, 'opeak': 3468.6092061611002, 'time': 9},
#  {'peak': 277752.6858351354, 'opeak': 3507.8723129711657, 'time': 10},
#  {'peak': 261422.87820450385, 'opeak': 3537.025017190586, 'time': 11},
#  {'peak': 270673.64253277576, 'opeak': 3568.247649065246, 'time': 12},
# ...
